# %%
class class1:
    v1 = "samran"
    v2 = 1

obj1 = class1()
print(obj1)
print(obj1.v1)
print(obj1.v2)
# Out:
# ...
# samran
# 1

# %%
obj2 = class1()
print(obj2.v1)
obj2.v1 = "ali"
print(obj2.v1)
# Out:
# samran
# ali

# %%
class class2:
    name = "samran"
    roll_no = 1

    def abc(self):
        print("name-->",self.name)

obj11 = class2()
obj11.abc()
obj11.name = "ali"
obj11.abc()
# Out:
# name--> samran
# name--> ali

# %%
class class3:
    def __init__(self,name):
        self.name = name

    roll_no = 1

    def abc(self):
        print("name-->",self.name)

obj111 = class3("abdullah")
print(obj111.name)
obj111.abc()
# Out:
# abdullah
# name--> abdullah
