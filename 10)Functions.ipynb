# %%
def function1():
  print("Hello and Welcome Dosto")

# %%
function1()
# Out:
# Hello and Welcome Dosto

# %%
def function2(plus):
  print("Hello and Welcome Dosto",plus)

function2('to dsa course')
# Out:
# Hello and Welcome Dosto to dsa course

# %%
def function2(plus):
  print("Hello and Welcome Dosto " + plus)

function2('to phython course')
# Out:
# Hello and Welcome Dosto to phython course

# %%
def name(fname,lname):
  print(fname + " " + lname)

name('samran','ali')
# Out:
# samran ali

# %%
name('abdullah','ali')
# Out:
# abdullah ali

# %%
def function2(*plus):
  print("Hello and Welcome Dosto", plus[0],plus[1],plus[2] )

function2('to phython course','and','to dsa course')
# Out:
# Hello and Welcome Dosto to phython course and to dsa course

# %%
def name1(lname,fname):
  print(fname + " " + lname)

name1(fname = 'samran',lname = 'ali')
# Out:
# samran ali

# %%
def name2(**student):
  print(student['fname'] + " " + student['lname'])

name2(fname = 'samran',lname = 'ali')
# Out:
# samran ali

# %%
def name3(**students):
  print(students['s1'],students['s2'],students['s3'])

name3(s1 = 'samran',s2 = 'abdullah',s3 = 'ali')
# Out:
# samran abdullah ali

# %%
def function2(plus = 'to phython course'):
  print("Hello and Welcome Dosto",plus)

function2('to dsa course')
function2()
# Out:
# Hello and Welcome Dosto to dsa course
# Hello and Welcome Dosto to phython course

# %%
def sum_fun(a,b):
  c = a+b
  return c

sum_fun(1,2)
# Out:
# 3

# %%
sum_fun(2,3)
# Out:
# 5

# %%
square = lambda x: x * x * x
print(square(6))
# Out:
# 216

# %%
add = lambda a, b: a + b
print(add(10, 20))
# Out:
# 30

# %%
numbers = [1, 2, 3]
squares = list(map(lambda x: x**2, numbers))
print(squares)
# Out:
# [1, 4, 9]

# %%
def countdown(n):
    if n == 0:
        return
    print(n)
    countdown(n - 1)

countdown(3)
# Out:
# 3
# 2
# 1

# %%
def total(n):
    if n == 0:
        return 0
    return n + total(n - 1)

print(total(5))
# Out:
# 15
